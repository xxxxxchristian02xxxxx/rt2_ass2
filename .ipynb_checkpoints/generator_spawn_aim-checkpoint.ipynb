# %%
import numpy as np, random
import matplotlib.pyplot as plt
import yaml


def get_random(num_departures, code):
    count = 0
    random_vector = []
    while count != num_departures:
        num_x = random.randint(-9, 9)
        num_y = random.randint(-9, 9)
        rand_pos = (num_x, num_y)
        if verify_target(rand_pos, random_vector) and code == 1 :
            random_vector.append(rand_pos)
            count += 1
        elif verify_target_telep(rand_pos, random_vector) and code == 2:
            random_vector.append(rand_pos)
            count += 1
    return random_vector

def verify_target(rand_pos, existing_positions):
    if rand_pos in existing_positions: 
        return False
    x_pos, y_pos = rand_pos 
    if  (
        (-5.5 <= x_pos <= 4 and -1 <= y_pos <= 0.5) or
        (-5.5 <= x_pos <= 4 and -5 <= y_pos <= 0.5) or
        (-7 <= x_pos <= 5 and 4 <= y_pos <= 5)

        ):
        return False
    return True


def verify_target_telep(rand_pos, existing_positions):
    if rand_pos in existing_positions: 
        return False
    x_pos, y_pos = rand_pos 
    if (
        (-5.5 <= x_pos <= 4 and -1 <= y_pos <= 0.5) or
        (-5.5 <= x_pos <= 4 and -5 <= y_pos <= 0.5) or
        (-7 <= x_pos <= 5 and 4 <= y_pos <= 5) or
        (x_pos >= 8 and y_pos >= 7) or
        not (-8 <= x_pos <= 8 and -8 <= y_pos <= 8)
    ):
        return False
    return True


num_departures = 100
random_positions_target = get_random(num_departures,1)
random_positions_spawn = get_random(num_departures*2,2)

# random_positions_target = [(3, -5),(-8, -7),(2,-3)]
# random_positions_target = [(-8, -7),(3, -5),(2,-3)]

target_random_list =random_positions_target
print(f'positions:{random_positions_target}')
random_spawn_position =random_positions_spawn
print(f'spawn:{random_positions_spawn}')

# fig, ax = plt.subplots()
# ax.hist(random_positions, bins=30, density=True, alpha=0.6, color='b', edgecolor='black')
# ax.set_title('Istogramma dei Dati (Truncated Normal)')
# ax.set_xlabel('Valori')
# ax.set_ylabel('Densità')
# plt.show()



with open("random_targets_generated.yaml", "w") as f:
    pass
    yaml.dump([list(pos) for pos in target_random_list], f)


with open("random_spawn_positions.yaml", "w") as f_p:
    pass
    yaml.dump([list(pos) for pos in random_spawn_position], f_p)
# Out:
# positions:[(6, -7), (7, -8), (5, -1), (4, 7), (4, -8), (9, 2), (-4, 7), (-2, 6), (2, 9), (7, -3), (0, -7), (-5, 7), (-3, 7), (2, -8), (4, 2), (3, -9), (7, 1), (-3, -7), (-4, -9), (-9, -7), (0, 9), (6, 0), (8, -5), (-1, -8), (4, 3), (-7, 9), (8, 5), (-5, 9), (0, -8), (2, -7), (4, -6), (-9, -3), (-1, -6), (-3, -8), (5, -2), (-2, -6), (-9, 4), (7, 9), (9, 5), (8, 9), (-1, 9), (-3, 9), (-9, 8), (1, -8), (-9, 9), (5, -3), (9, 4), (0, 2), (-1, 2), (9, 3), (4, -9), (6, -9), (7, 5), (-7, 0), (8, -3), (-5, -8), (8, -2), (-7, -8), (-6, -5), (-3, -9), (9, 7), (6, 4), (-7, 6), (2, 3), (7, -7), (-9, -9), (3, 3), (-7, 3), (0, 8), (-7, 7), (9, -5), (6, 8), (1, 8), (-4, 1), (6, -5), (1, 6), (-5, 8), (-1, -7), (-8, -7), (-8, 8), (7, -9), (-6, 0), (-9, -8), (0, -9), (-5, -9), (-8, 4), (9, -6), (5, -4), (6, -3), (8, 4), (1, 7), (-5, 3), (9, -1), (8, -4), (-1, 3), (5, -5), (-2, 8), (6, 1), (-3, 1), (-1, 8)]
# spawn:[(7, -2), (3, 6), (-4, 7), (8, -8), (-6, -7), (-3, -7), (-7, 8), (5, 6), (-8, 5), (-5, 3), (-6, -4), (6, 6), (8, 2), (-6, -2), (-7, -6), (-2, 2), (6, 5), (-2, 6), (8, 6), (-8, -5), (-1, 7), (-2, -7), (-8, 4), (-1, 6), (-2, 1), (-1, -7), (-6, 6), (5, -3), (-8, -4), (3, -6), (-7, 0), (0, 3), (5, 1), (-6, -5), (7, 0), (7, -4), (1, 8), (-4, 3), (8, -5), (-3, 3), (7, 1), (0, 2), (-8, 1), (7, 7), (-6, -3), (5, -8), (-8, 0), (-3, 1), (-1, 2), (0, 7), (-7, 2), (-1, 1), (-8, -3), (-5, 2), (8, 0), (3, 1), (-7, 6), (8, -6), (-6, 0), (7, 4), (6, -5), (-2, -6), (-8, 8), (3, 8), (-4, -7), (4, 8), (-4, -8), (-1, -8), (-8, 3), (7, 3), (5, -2), (7, -7), (8, -2), (4, 2), (-2, 7), (1, 6), (-6, 8), (-6, 1), (8, 5), (6, -6), (1, 1), (5, 2), (4, -8), (1, 2), (-8, -6), (-7, -4), (-4, 1), (2, 7), (-7, 3), (7, 5), (4, 1), (-8, 7), (3, -7), (-2, 3), (-7, -8), (-6, 2), (-5, 7), (0, -7), (3, 2), (3, 7), (-8, -1), (6, 7), (8, -7), (5, -1), (4, -7), (-5, 8), (-8, -8), (-5, 6), (-6, -6), (5, 3), (-4, 6), (7, -1), (5, -5), (4, -6), (-7, -1), (-3, -8), (6, -2), (2, 2), (-2, -8), (2, -6), (3, 3), (7, -6), (3, -8), (-3, 2), (7, 6), (-8, 2), (5, 7), (6, 8), (-4, 2), (6, 2), (7, -3), (-3, 8), (0, 6), (-6, -1), (1, 3), (-7, 7), (-6, 7), (-4, 8), (-8, -7), (-7, -3), (-7, -2), (-1, -6), (-5, -6), (7, 2), (-1, 8), (-4, -6), (6, 4), (5, -7), (5, 8), (4, 6), (2, 6), (8, -4), (6, -4), (-8, -2), (0, 1), (6, -8), (5, 0), (7, -5), (6, -1), (-2, 8), (7, -8), (1, -7), (8, 1), (-5, -8), (2, 8), (4, 7), (8, -1), (0, 8), (1, 7), (6, -7), (2, -7), (6, 3), (8, -3), (-1, 3), (0, -8), (2, -8), (6, -3), (0, -6), (-5, 1), (2, 1), (5, -6), (2, 3), (7, 8), (6, 1), (-5, -7), (8, 4), (-7, -5), (8, 3), (-3, -6), (1, -6), (-3, 7), (-6, -8), (-7, -7), (1, -8), (4, 3), (-7, 1), (5, -4), (-8, 6), (-3, 6), (-6, 3)]

# %%
print(random_positions_target)
# Out:
# [(6, -7), (7, -8), (5, -1), (4, 7), (4, -8), (9, 2), (-4, 7), (-2, 6), (2, 9), (7, -3), (0, -7), (-5, 7), (-3, 7), (2, -8), (4, 2), (3, -9), (7, 1), (-3, -7), (-4, -9), (-9, -7), (0, 9), (6, 0), (8, -5), (-1, -8), (4, 3), (-7, 9), (8, 5), (-5, 9), (0, -8), (2, -7), (4, -6), (-9, -3), (-1, -6), (-3, -8), (5, -2), (-2, -6), (-9, 4), (7, 9), (9, 5), (8, 9), (-1, 9), (-3, 9), (-9, 8), (1, -8), (-9, 9), (5, -3), (9, 4), (0, 2), (-1, 2), (9, 3), (4, -9), (6, -9), (7, 5), (-7, 0), (8, -3), (-5, -8), (8, -2), (-7, -8), (-6, -5), (-3, -9), (9, 7), (6, 4), (-7, 6), (2, 3), (7, -7), (-9, -9), (3, 3), (-7, 3), (0, 8), (-7, 7), (9, -5), (6, 8), (1, 8), (-4, 1), (6, -5), (1, 6), (-5, 8), (-1, -7), (-8, -7), (-8, 8), (7, -9), (-6, 0), (-9, -8), (0, -9), (-5, -9), (-8, 4), (9, -6), (5, -4), (6, -3), (8, 4), (1, 7), (-5, 3), (9, -1), (8, -4), (-1, 3), (5, -5), (-2, 8), (6, 1), (-3, 1), (-1, 8)]

# %%
print(random_positions_spawn)
# Out:
# [(7, -2), (3, 6), (-4, 7), (8, -8), (-6, -7), (-3, -7), (-7, 8), (5, 6), (-8, 5), (-5, 3), (-6, -4), (6, 6), (8, 2), (-6, -2), (-7, -6), (-2, 2), (6, 5), (-2, 6), (8, 6), (-8, -5), (-1, 7), (-2, -7), (-8, 4), (-1, 6), (-2, 1), (-1, -7), (-6, 6), (5, -3), (-8, -4), (3, -6), (-7, 0), (0, 3), (5, 1), (-6, -5), (7, 0), (7, -4), (1, 8), (-4, 3), (8, -5), (-3, 3), (7, 1), (0, 2), (-8, 1), (7, 7), (-6, -3), (5, -8), (-8, 0), (-3, 1), (-1, 2), (0, 7), (-7, 2), (-1, 1), (-8, -3), (-5, 2), (8, 0), (3, 1), (-7, 6), (8, -6), (-6, 0), (7, 4), (6, -5), (-2, -6), (-8, 8), (3, 8), (-4, -7), (4, 8), (-4, -8), (-1, -8), (-8, 3), (7, 3), (5, -2), (7, -7), (8, -2), (4, 2), (-2, 7), (1, 6), (-6, 8), (-6, 1), (8, 5), (6, -6), (1, 1), (5, 2), (4, -8), (1, 2), (-8, -6), (-7, -4), (-4, 1), (2, 7), (-7, 3), (7, 5), (4, 1), (-8, 7), (3, -7), (-2, 3), (-7, -8), (-6, 2), (-5, 7), (0, -7), (3, 2), (3, 7), (-8, -1), (6, 7), (8, -7), (5, -1), (4, -7), (-5, 8), (-8, -8), (-5, 6), (-6, -6), (5, 3), (-4, 6), (7, -1), (5, -5), (4, -6), (-7, -1), (-3, -8), (6, -2), (2, 2), (-2, -8), (2, -6), (3, 3), (7, -6), (3, -8), (-3, 2), (7, 6), (-8, 2), (5, 7), (6, 8), (-4, 2), (6, 2), (7, -3), (-3, 8), (0, 6), (-6, -1), (1, 3), (-7, 7), (-6, 7), (-4, 8), (-8, -7), (-7, -3), (-7, -2), (-1, -6), (-5, -6), (7, 2), (-1, 8), (-4, -6), (6, 4), (5, -7), (5, 8), (4, 6), (2, 6), (8, -4), (6, -4), (-8, -2), (0, 1), (6, -8), (5, 0), (7, -5), (6, -1), (-2, 8), (7, -8), (1, -7), (8, 1), (-5, -8), (2, 8), (4, 7), (8, -1), (0, 8), (1, 7), (6, -7), (2, -7), (6, 3), (8, -3), (-1, 3), (0, -8), (2, -8), (6, -3), (0, -6), (-5, 1), (2, 1), (5, -6), (2, 3), (7, 8), (6, 1), (-5, -7), (8, 4), (-7, -5), (8, 3), (-3, -6), (1, -6), (-3, 7), (-6, -8), (-7, -7), (1, -8), (4, 3), (-7, 1), (5, -4), (-8, 6), (-3, 6), (-6, 3)]
